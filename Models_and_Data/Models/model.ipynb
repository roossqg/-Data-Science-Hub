# %%
import pandas as pd
import matplotlib.pyplot  as plt
import numpy
#import mglearn


from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

iris=load_iris()
#print(iris['data'])
dta_train,dta_data,target_train,target_data=train_test_split(iris["data"],iris["target"],random_state=0)
print(f"one: {dta_train.shape},two : {target_train.shape}")


#saving the data:



data_fra=pd.DataFrame(dta_train,columns=iris.feature_names)
print(iris['feature_names'])
#dta_trainn=pd.Series(dta_train)
print(data_fra)
#sca=pd.scatter_matrix(data_fra,c=["r","b","purple"],figsize=(12,12),marker="o")
plt.scatter(data_fra['sepal width (cm)'],data_fra['petal length (cm)'],c=target_train) #colors using the train preset as represents
#print(sca)
plt.ylabel("petal legth")
plt.xlabel("sepal width")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot  as plt
#       3 import numpy
#       4 #import mglearn
#
# File c:\Users\augusto\.vscode\Data Sci and Ml\Machine_Learnig\.venv\Lib\site-packages\matplotlib\__init__.py:1001
#     995     _log.debug('loaded rc file %s', fname)
#     997     return config
#    1000 rcParamsDefault = _rc_params_in_file(
# -> 1001     cbook._get_data_path("matplotlibrc"),
#    1002     # Strip leading comment.
#    1003     transform=lambda line: line[1:] if line.startswith("#") else line,
#    1004     fail_on_error=True)
#    1005 rcParamsDefault._update_raw(rcsetup._hardcoded_defaults)
#    1006 rcParamsDefault._ensure_has_backend()
#
# ...
